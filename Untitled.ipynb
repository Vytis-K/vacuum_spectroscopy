# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Define the Gaussian function
def gaussian(x, amp, cen, wid):
    return amp * np.exp(-(x - cen)**2 / (2 * wid**2))

# Define the function to fit multiple Gaussians to the data
def multi_gaussian(x, *params):
    n_peaks = len(params) // 3
    y = np.zeros_like(x)
    for i in range(n_peaks):
        amp = params[3*i]
        cen = params[3*i+1]
        wid = params[3*i+2]
        y += gaussian(x, amp, cen, wid)
    return y

# Generate some example data with two Gaussian peaks
xdata = [35.5,35.6,35.7,35.8,35.9,36,36.1,36.2,36.3,36.4,36.5,36.6,36.7,36.8,36.9,37,37.1,37.2,37.3,37.4,37.5,37.6,37.7,37.8,37.9,38,38.1,38.2,38.3,38.4,38.5,38.6,38.7,38.8,38.9,39,39.1,39.2,39.3,39.4,39.5,39.6,39.7,39.8,39.9,40,40.1,40.2,40.3,40.4,40.5,40.6,40.7,40.8,40.9,41]
ydata = [0.00000000215,0.00000000215,0.00000000215,0.00000000215,0.00000000215,0.00000000215,-0.000000000367,0.00000000215,0.000000003,0.000000003,0.00000000215,0.00000000215,0.00000000215,0.00000000215,0.00000000215,0.00000000474,0.0000000116,0.0000000102,0.00000000657,0.00000000933,0.00000000657,0.00000000933,0.0000000102,0.0000000168,0.0000000243,0.0000000329,0.0000000636,0.000000098,0.000000151,0.000000262,0.000000406,0.000000559,0.000000781,0.00000112,0.00000185,0.00000436,0.00000483,0.00000158,0.000000428,0.000000183,0.000000098,0.0000000646,0.0000000555,0.0000000555,0.0000000728,0.000000133,0.000000219,0.00000016,0.0000000749,0.0000000377,0.0000000243,0.0000000102,0.00000000933,0.00000000657,0.000000003,0.000000003]

x = np.asarray(xdata)
y = np.asarray(ydata)


# Plot the example data
plt.figure()
plt.plot(x, y, '.', label='Data')

# Fit the multiple Gaussian function to the data
p0 = [3e-9, 37, 1, 3e-9, 39, 1]  # Initial guess for parameters
popt, pcov = curve_fit(multi_gaussian, x, y, p0=p0)

# Plot the fitted function
y_fit = multi_gaussian(x, *popt)
plt.plot(x, y_fit, '-', label='Fit')

# Plot the individual Gaussian components
n_peaks = len(popt) // 3
for i in range(n_peaks):
    amp = popt[3*i]
    cen = popt[3*i+1]
    wid = popt[3*i+2]
    plt.plot(x, gaussian(x, amp, cen, wid), '--', label=f'Peak {i+1}')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Define the Gaussian function
def gaussian(x, amp, cen, wid):
    return amp * np.exp(-(x - cen)**2 / (2 * wid**2))

# Define the function to fit multiple Gaussians to the data
def multi_gaussian(x, *params):
    n_peaks = len(params) // 3
    y = np.zeros_like(x)
    for i in range(n_peaks):
        amp = params[3*i]
        cen = params[3*i+1]
        wid = params[3*i+2]
        y += gaussian(x, amp, cen, wid)
    return y

# Generate some example data with two Gaussian peaks
xdata = [128.2,128.3,128.4,128.5,128.6,128.7,128.8,128.9,129,129.1,129.2,129.3,129.4,129.5,129.6,129.7,129.8,129.9,130,130.1,130.2,130.3,130.4,130.5,130.6,130.7,130.8,130.9,131,131.1,131.2,131.3,131.4,131.5,131.6,131.7,131.8,131.9,132,132.1,132.2,132.3,132.4,132.5,132.6,132.7,132.8,132.9,133,133.1,133.2,133.3,133.4,133.5,133.6,133.7,133.8,133.9,134,134.1,134.2,134.3,134.4,134.5,134.6,134.7,134.8,134.9,135,135.1,135.2,135.3,135.4,135.5,135.6,135.7,135.8,135.9,136,136.1,136.2]
ydata = [0.0000000188,0.0000000235,0.0000000321,0.0000000418,0.0000000399,0.0000000321,0.0000000244,0.0000000235,0.0000000235,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000235,0.0000000244,0.0000000311,0.000000036,0.000000033,0.0000000263,0.0000000235,0.0000000188,0.0000000169,0.0000000169,0.0000000169,0.0000000235,0.0000000254,0.000000034,0.0000000311,0.0000000263,0.0000000235,0.000000021,0.00000002,0.0000000188,0.0000000188,0.0000000188,0.0000000169,0.0000000169,0.0000000169,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.0000000235,0.0000000235,0.000000023,0.0000000188,0.0000000169,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.0000000169,0.0000000188,0.0000000195,0.0000000188,0.000000016,0.000000016,0.000000016,0.000000016]

x = np.asarray(xdata)
y = np.asarray(ydata)


# Plot the example data
plt.figure()
plt.plot(x, y, '.', label='Data')

# Fit the multiple Gaussian function to the data
p0 = [4e-8, 128.5, 1, 3.5e-8, 130.5, 1]  # Initial guess for parameters
popt, pcov = curve_fit(multi_gaussian, x, y, p0=p0)

# Plot the fitted function
y_fit = multi_gaussian(x, *popt)
plt.plot(x, y_fit, '-', label='Fit')

# Plot the individual Gaussian components
n_peaks = len(popt) // 3
for i in range(n_peaks):
    amp = popt[3*i]
    cen = popt[3*i+1]
    wid = popt[3*i+2]
    plt.plot(x, gaussian(x, amp, cen, wid), '--', label=f'Peak {i+1}')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 34
#      32 # Fit the multiple Gaussian function to the data
#      33 p0 = [4e-8, 128.5, 1, 3.5e-8, 130.5, 1]  # Initial guess for parameters
# ---> 34 popt, pcov = curve_fit(multi_gaussian, x, y, p0=p0)
#      36 # Plot the fitted function
#      37 y_fit = multi_gaussian(x, *popt)
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:864, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     862     cost = np.sum(infodict['fvec'] ** 2)
#     863     if ier not in [1, 2, 3, 4]:
# --> 864         raise RuntimeError("Optimal parameters not found: " + errmsg)
#     865 else:
#     866     # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#     867     if 'max_nfev' not in kwargs:
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# Define the sum of five Gaussian functions
def gaussian_sum(x, *params):
    A1, mu1, sigma1, A2, mu2, sigma2, A3, mu3, sigma3, A4, mu4, sigma4, A5, mu5, sigma5 = params
    return (A1*np.exp(-(x-mu1)**2/(2*sigma1**2)) + A2*np.exp(-(x-mu2)**2/(2*sigma2**2)) +
            A3*np.exp(-(x-mu3)**2/(2*sigma3**2)) + A4*np.exp(-(x-mu4)**2/(2*sigma4**2)) +
            A5*np.exp(-(x-mu5)**2/(2*sigma5**2)))

# data with five Gaussian peaks
xdata = [128.2,128.3,128.4,128.5,128.6,128.7,128.8,128.9,129,129.1,129.2,129.3,129.4,129.5,129.6,129.7,129.8,129.9,130,130.1,130.2,130.3,130.4,130.5,130.6,130.7,130.8,130.9,131,131.1,131.2,131.3,131.4,131.5,131.6,131.7,131.8,131.9,132,132.1,132.2,132.3,132.4,132.5,132.6,132.7,132.8,132.9,133,133.1,133.2,133.3,133.4,133.5,133.6,133.7,133.8,133.9,134,134.1,134.2,134.3,134.4,134.5,134.6,134.7,134.8,134.9,135,135.1,135.2,135.3,135.4,135.5,135.6,135.7,135.8,135.9,136,136.1,136.2]
ydata = [0.0000000188,0.0000000235,0.0000000321,0.0000000418,0.0000000399,0.0000000321,0.0000000244,0.0000000235,0.0000000235,0.0000000188,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000188,0.0000000235,0.0000000244,0.0000000311,0.000000036,0.000000033,0.0000000263,0.0000000235,0.0000000188,0.0000000169,0.000000016,0.0000000169,0.0000000235,0.0000000254,0.000000034,0.0000000311,0.0000000263,0.0000000235,0.000000021,0.00000002,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.00000002,0.0000000235,0.000000023,0.0000000188,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.0000000169,0.0000000188,0.0000000195,0.0000000188,0.000000016,0.000000016,0.000000016,0.000000016]

x = np.asarray(xdata)
y = np.asarray(ydata)

# finding the inital guess and peaks
peaks, _ = find_peaks(y)
A_guess = [y[p] for p in peaks]
mu_guess = [x[p] for p in peaks]
sigma_guess = [0.4] * len(peaks)


# Fit the Gaussian function to the data
initial_guess = [p for params in zip(A_guess, mu_guess, sigma_guess) for p in params]
popt, pcov = curve_fit(gaussian_sum, x, y, p0=initial_guess)

# Plot the data and fitted function
plt.plot(x, y, 'b.', label='Data')
plt.plot(x, gaussian_sum(x, *popt), 'r-', label='Fit')
plt.legend()

plt.xlabel('AMU')
plt.ylabel('Pressure (Torr)')
plt.title('Xenon Isotope Fits')

plt.show()

# %%
initial_guess = [4e-8, 128.5, 0.2, 3.5e-8, 130.5, 0.2, 3.5e-8, 131.5, 0.15, 2.4e-8, 133.5, 0.3, 2e-8, 135.5, 0.2]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# Define the sum of five Gaussian functions
def gaussian_sum(x, *params):
    A1, mu1, sigma1, A2, mu2, sigma2, A3, mu3, sigma3, A4, mu4, sigma4, A5, mu5, sigma5 = params
    return (A1*np.exp(-(x-mu1)**2/(2*sigma1**2)) + A2*np.exp(-(x-mu2)**2/(2*sigma2**2)) +
            A3*np.exp(-(x-mu3)**2/(2*sigma3**2)) + A4*np.exp(-(x-mu4)**2/(2*sigma4**2)) +
            A5*np.exp(-(x-mu5)**2/(2*sigma5**2)))

# data with five Gaussian peaks
xdata = [128.2,128.3,128.4,128.5,128.6,128.7,128.8,128.9,129,129.1,129.2,129.3,129.4,129.5,129.6,129.7,129.8,129.9,130,130.1,130.2,130.3,130.4,130.5,130.6,130.7,130.8,130.9,131,131.1,131.2,131.3,131.4,131.5,131.6,131.7,131.8,131.9,132,132.1,132.2,132.3,132.4,132.5,132.6,132.7,132.8,132.9,133,133.1,133.2,133.3,133.4,133.5,133.6,133.7,133.8,133.9,134,134.1,134.2,134.3,134.4,134.5,134.6,134.7,134.8,134.9,135,135.1,135.2,135.3,135.4,135.5,135.6,135.7,135.8,135.9,136,136.1,136.2]
ydata = [0.0000000188,0.0000000235,0.0000000321,0.0000000418,0.0000000399,0.0000000321,0.0000000244,0.0000000235,0.0000000235,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000235,0.0000000244,0.0000000311,0.000000036,0.000000033,0.0000000263,0.0000000235,0.0000000188,0.0000000169,0.0000000169,0.0000000169,0.0000000235,0.0000000254,0.000000034,0.0000000311,0.0000000263,0.0000000235,0.000000021,0.00000002,0.0000000188,0.0000000188,0.0000000188,0.0000000169,0.0000000169,0.0000000169,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.0000000235,0.0000000235,0.000000023,0.0000000188,0.0000000169,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.0000000169,0.0000000188,0.0000000195,0.0000000188,0.000000016,0.000000016,0.000000016,0.000000016]

x = np.asarray(xdata)
y = np.asarray(ydata)

# finding the inital guess and peaks
peaks, _ = find_peaks(y)
A_guess = [y[p] for p in peaks]
mu_guess = [x[p] for p in peaks]
sigma_guess = [0.4] * len(peaks)

# Fit the Gaussian function to the data
initial_guess = [p for params in zip(A_guess, mu_guess, sigma_guess) for p in params]
popt, pcov = curve_fit(gaussian_sum, x, y, p0=initial_guess)

# Plot the data and fitted function
plt.plot(x, y, 'b.', label='Data')
plt.plot(x, gaussian_sum(x, *popt), 'r-', label='Fit')
plt.legend()

plt.xlabel('AMU')
plt.ylabel('Pressure (Torr)')
plt.title('Xenon Isotope Fits')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# Define the sum of five Gaussian functions
def gaussian_sum(x, *params):
    A1, mu1, sigma1, A2, mu2, sigma2, A3, mu3, sigma3, A4, mu4, sigma4, A5, mu5, sigma5 = params
    return (A1*np.exp(-(x-mu1)**2/(2*sigma1**2)) + A2*np.exp(-(x-mu2)**2/(2*sigma2**2)) +
            A3*np.exp(-(x-mu3)**2/(2*sigma3**2)) + A4*np.exp(-(x-mu4)**2/(2*sigma4**2)) +
            A5*np.exp(-(x-mu5)**2/(2*sigma5**2)))

# data with five Gaussian peaks
xdata = [128.2,128.3,128.4,128.5,128.6,128.7,128.8,128.9,129,129.1,129.2,129.3,129.4,129.5,129.6,129.7,129.8,129.9,130,130.1,130.2,130.3,130.4,130.5,130.6,130.7,130.8,130.9,131,131.1,131.2,131.3,131.4,131.5,131.6,131.7,131.8,131.9,132,132.1,132.2,132.3,132.4,132.5,132.6,132.7,132.8,132.9,133,133.1,133.2,133.3,133.4,133.5,133.6,133.7,133.8,133.9,134,134.1,134.2,134.3,134.4,134.5,134.6,134.7,134.8,134.9,135,135.1,135.2,135.3,135.4,135.5,135.6,135.7,135.8,135.9,136,136.1,136.2]
ydata = [0.0000000188,0.0000000235,0.0000000321,0.0000000418,0.0000000399,0.0000000321,0.0000000244,0.0000000235,0.0000000235,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000188,0.0000000235,0.0000000244,0.0000000311,0.000000036,0.000000033,0.0000000263,0.0000000235,0.0000000188,0.0000000169,0.0000000169,0.0000000169,0.0000000235,0.0000000254,0.000000034,0.0000000311,0.0000000263,0.0000000235,0.000000021,0.00000002,0.0000000188,0.0000000188,0.0000000188,0.0000000169,0.0000000169,0.0000000169,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.00000002,0.0000000235,0.000000021,0.0000000188,0.0000000169,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.0000000169,0.0000000188,0.0000000195,0.0000000188,0.000000016,0.000000016,0.000000016,0.000000016]

x = np.asarray(xdata)
y = np.asarray(ydata)

# finding the inital guess and peaks
peaks, _ = find_peaks(y)
A_guess = [y[p] for p in peaks]
mu_guess = [x[p] for p in peaks]
sigma_guess = [0.4] * len(peaks)

# Fit the Gaussian function to the data
initial_guess = [p for params in zip(A_guess, mu_guess, sigma_guess) for p in params]
popt, pcov = curve_fit(gaussian_sum, x, y, p0=initial_guess)

# Plot the data and fitted function
plt.plot(x, y, 'b.', label='Data')
plt.plot(x, gaussian_sum(x, *popt), 'r-', label='Fit')
plt.legend()

plt.xlabel('AMU')
plt.ylabel('Pressure (Torr)')
plt.title('Xenon Isotope Fits')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# Define the sum of five Gaussian functions
def gaussian_sum(x, *params):
    A1, mu1, sigma1, A2, mu2, sigma2, A3, mu3, sigma3, A4, mu4, sigma4, A5, mu5, sigma5 = params
    return (A1*np.exp(-(x-mu1)**2/(2*sigma1**2)) + A2*np.exp(-(x-mu2)**2/(2*sigma2**2)) +
            A3*np.exp(-(x-mu3)**2/(2*sigma3**2)) + A4*np.exp(-(x-mu4)**2/(2*sigma4**2)) +
            A5*np.exp(-(x-mu5)**2/(2*sigma5**2)))

# data with five Gaussian peaks
xdata = [128.2,128.3,128.4,128.5,128.6,128.7,128.8,128.9,129,129.1,129.2,129.3,129.4,129.5,129.6,129.7,129.8,129.9,130,130.1,130.2,130.3,130.4,130.5,130.6,130.7,130.8,130.9,131,131.1,131.2,131.3,131.4,131.5,131.6,131.7,131.8,131.9,132,132.1,132.2,132.3,132.4,132.5,132.6,132.7,132.8,132.9,133,133.1,133.2,133.3,133.4,133.5,133.6,133.7,133.8,133.9,134,134.1,134.2,134.3,134.4,134.5,134.6,134.7,134.8,134.9,135,135.1,135.2,135.3]
ydata = [0.0000000188,0.0000000235,0.0000000321,0.0000000418,0.0000000399,0.0000000321,0.0000000244,0.0000000235,0.0000000235,0.0000000188,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000188,0.0000000235,0.0000000244,0.0000000311,0.000000036,0.000000033,0.0000000263,0.0000000235,0.0000000188,0.0000000169,0.000000016,0.0000000169,0.0000000235,0.0000000254,0.000000034,0.0000000311,0.0000000263,0.0000000235,0.000000021,0.00000002,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.0000000169,0.00000002,0.0000000235,0.000000023,0.0000000188,0.0000000169,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016,0.000000016]

x = np.asarray(xdata)
y = np.asarray(ydata)

# finding the inital guess and peaks
peaks, _ = find_peaks(y)
A_guess = [y[p] for p in peaks]
mu_guess = [x[p] for p in peaks]
sigma_guess = [0.4] * len(peaks)


# Fit the Gaussian function to the data
initial_guess = [p for params in zip(A_guess, mu_guess, sigma_guess) for p in params]
popt, pcov = curve_fit(gaussian_sum, x, y, p0=initial_guess)

# Plot the data and fitted function
plt.plot(x, y, 'b.', label='Data')
plt.plot(x, gaussian_sum(x, *popt), 'r-', label='Fit')
plt.legend()

plt.xlabel('AMU')
plt.ylabel('Pressure (Torr)')
plt.title('Xenon Isotope Fits')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 29
#      27 # Fit the Gaussian function to the data
#      28 initial_guess = [p for params in zip(A_guess, mu_guess, sigma_guess) for p in params]
# ---> 29 popt, pcov = curve_fit(gaussian_sum, x, y, p0=initial_guess)
#      31 # Plot the data and fitted function
#      32 plt.plot(x, y, 'b.', label='Data')
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:859, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     856 if ydata.size != 1 and n > ydata.size:
#     857     raise TypeError(f"The number of func parameters={n} must not"
#     858                     f" exceed the number of data points={ydata.size}")
# --> 859 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

def _2gaussian(x, amp1,cen1,sigma1, amp2,cen2,sigma2):
    return amp1*(1/(sigma1*(np.sqrt(2*np.pi))))*(np.exp((-1.0/2.0)*(((x_array-cen1)/sigma1)**2))) + \
            amp2*(1/(sigma2*(np.sqrt(2*np.pi))))*(np.exp((-1.0/2.0)*(((x_array-cen2)/sigma2)**2)))

popt_2gauss, pcov_2gauss = scipy.optimize.curve_fit(_2gaussian, x_array, y_array_2gauss, p0=[amp1, cen1, sigma1, amp2, cen2, sigma2])
perr_2gauss = np.sqrt(np.diag(pcov_2gauss))
pars_1 = popt_2gauss[0:3]
pars_2 = popt_2gauss[3:6]
gauss_peak_1 = _1gaussian(x_array, *pars_1)
gauss_peak_2 = _1gaussian(x_array, *pars_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 def _2gaussian(x, amp1,cen1,sigma1, amp2,cen2,sigma2):
#       7     return amp1*(1/(sigma1*(np.sqrt(2*np.pi))))*(np.exp((-1.0/2.0)*(((x_array-cen1)/sigma1)**2))) + \
#       8             amp2*(1/(sigma2*(np.sqrt(2*np.pi))))*(np.exp((-1.0/2.0)*(((x_array-cen2)/sigma2)**2)))
# ---> 10 popt_2gauss, pcov_2gauss = scipy.optimize.curve_fit(_2gaussian, x_array, y_array_2gauss, p0=[amp1, cen1, sigma1, amp2, cen2, sigma2])
#      11 perr_2gauss = np.sqrt(np.diag(pcov_2gauss))
#      12 pars_1 = popt_2gauss[0:3]
#
# NameError: name 'scipy' is not defined
